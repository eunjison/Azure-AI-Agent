# %% [markdown]
# ## Magentic One
#
# ![magentic](https://www.microsoft.com/en-us/research/uploads/prod/2024/11/magnetic_example-2048x1155.png)

# %% [markdown]
# ## MagenticOne - Microsoft의 멀티 에이전트 팀
#
# **MagenticOne**은 Microsoft Research에서 개발한 고성능 멀티 에이전트 시스템입니다. 하나의 **Orchestrator**(조정자)가 여러 전문화된 에이전트들을 관리하여 복잡한 작업을 수행합니다.
#
# ### 🎯 핵심 에이전트들
#
# 1. **🌐 WebSurfer**: 웹 브라우징 및 정보 검색
# 2. **📁 FileSurfer**: 파일 시스템 탐색 및 문서 처리
# 3. **💻 Coder**: 코드 작성 및 프로그래밍
# 4. **⚡ Executor**: 코드 실행 및 결과 처리
# 5. **🎭 Orchestrator**: 전체 팀 조정 및 작업 분배
#
# ### 🔧 주요 특징
# - **자율적 협업**: 에이전트들이 스스로 협력하여 목표 달성
# - **멀티모달**: 텍스트, 이미지, 파일 등 다양한 데이터 처리
# - **웹 자동화**: 실제 웹사이트 브라우징 및 상호작용
# - **코드 실행**: 실시간 코드 생성 및 실행
#
# ### 💡 사용 사례
# - 📊 데이터 분석 및 시각화
# - 🔍 웹 리서치 및 정보 수집
# - 📝 보고서 자동 생성
# - 🤖 복합적인 자동화 작업

# %% [markdown]
# ### `magentic_one.py` core code
#
# ```python
# def __init__(self, client: ChatCompletionClient, hil_mode: bool = False):
#     self.client = client
#     self._validate_client_capabilities(client)
#
#     fs = FileSurfer("FileSurfer", model_client=client)
#     ws = MultimodalWebSurfer("WebSurfer", model_client=client)
#     coder = MagenticOneCoderAgent("Coder", model_client=client)
#     executor = CodeExecutorAgent("Executor", code_executor=LocalCommandLineCodeExecutor())
#     agents: List[ChatAgent] = [fs, ws, coder, executor]
#     if hil_mode:
#         user_proxy = UserProxyAgent("User")
#         agents.append(user_proxy)
#     super().__init__(agents, model_client=client)
#
# ```

# %%
# MagenticOne에 필요한 추가 패키지 설치
import subprocess
import sys

def install_package(package):
    """패키지 설치 함수"""
    try:
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        print(f"✅ {package} 설치 완료")
    except subprocess.CalledProcessError as e:
        print(f"❌ {package} 설치 실패: {e}")

# MagenticOne 의존성 설치
required_packages = [
    "markitdown>=0.0.1",
    "playwright>=1.40.0"
]

print("🔧 MagenticOne 의존성 패키지 설치 중...")
for package in required_packages:
    install_package(package)

print("📦 설치 완료! MagenticOne을 사용할 준비가 되었습니다.")

# %%
# MagenticOne을 사용한 자율적 작업 수행
import asyncio
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_ext.teams.magentic_one import MagenticOne
from autogen_agentchat.ui import Console

from dotenv import load_dotenv
import os

load_dotenv()

# Azure OpenAI 설정
api_version = os.getenv("AZURE_OPENAI_API_VERSION")
api_key = os.getenv("AZURE_OPENAI_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")

print("🔧 Azure OpenAI 설정:")
print(f"   Endpoint: {azure_endpoint}")
print(f"   Deployment: {deployment_name}")
print(f"   API Version: {api_version}")

azure_openai_chat_completion_client = AzureOpenAIChatCompletionClient(
    model=deployment_name,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
    api_key=api_key,
)

print("\n🤖 MagenticOne 팀 초기화 중...")
client = azure_openai_chat_completion_client
m1 = MagenticOne(client=client)

print("📋 작업 실행:")
task = "마이크로소프트 현재 주가와 전망에 대해 알려줘"
print(f"   Task: {task}")

print("\n🚀 MagenticOne 팀 실행 시작...")
try:
    result = await Console(m1.run_stream(task=task))
    print(f"\n✅ 작업 완료!")
    print(f"Result: {result}")
except Exception as e:
    print(f"\n❌ 오류 발생: {e}")
    print("MagenticOne 실행 중 문제가 발생했습니다.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 4
#       2 import asyncio
#       3 from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
# ----> 4 from autogen_ext.teams.magentic_one import MagenticOne
#       5 from autogen_agentchat.ui import Console
#       7 from dotenv import load_dotenv
#
# File ~/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/teams/magentic_one.py:11
#       8 from autogen_core.code_executor import CodeExecutor
#       9 from autogen_core.models import ChatCompletionClient
# ---> 11 from autogen_ext.agents.file_surfer import FileSurfer
#      12 from autogen_ext.agents.magentic_one import MagenticOneCoderAgent
#      13 from autogen_ext.agents.web_surfer import MultimodalWebSurfer
#
# File ~/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/file_surfer/__init__.py:1
# ----> 1 from ._file_surfer import FileSurfer
#       3 __all__ = ["FileSurfer"]
#
# File ~/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/file_surfer/_file_surfer.py:24
#      21 from pydantic import BaseModel
#      22 from typing_extensions import Self
# ---> 24 from ._markdown_file_browser import MarkdownFileBrowser
#      26 # from typing_extensions import Annotated
#      27 from ._tool_definitions import (
#      28     TOOL_FIND_NEXT,
#      29     TOOL_FIND_ON_PAGE_CTRL_F,
#    (...)     32     TOOL_PAGE_UP,
#      33 )
#
# File ~/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/file_surfer/_markdown_file_browser.py:10
#       7 from typing import List, Optional, Tuple, Union
#       9 # TODO: Fix unfollowed import
# ---> 10 from markitdown import FileConversionException, MarkItDown, UnsupportedFormatException  # type: ignore
#      13 class MarkdownFileBrowser:
#      14     """
#      15     (In preview) An extremely simple Markdown-powered file browser.
#      16     """
#
# ModuleNotFoundError: No module named 'markitdown'
