# %% [markdown]
# ## Magentic One
#
# ![magentic](https://www.microsoft.com/en-us/research/uploads/prod/2024/11/magnetic_example-2048x1155.png)

# %% [markdown]
# ## MagenticOne - Microsoft의 멀티 에이전트 팀
#
# **MagenticOne**은 Microsoft Research에서 개발한 고성능 멀티 에이전트 시스템입니다. 하나의 **Orchestrator**(조정자)가 여러 전문화된 에이전트들을 관리하여 복잡한 작업을 수행합니다.
#
# ### 🎯 핵심 에이전트들
#
# 1. **🌐 WebSurfer**: 웹 브라우징 및 정보 검색
# 2. **📁 FileSurfer**: 파일 시스템 탐색 및 문서 처리
# 3. **💻 Coder**: 코드 작성 및 프로그래밍
# 4. **⚡ Executor**: 코드 실행 및 결과 처리
# 5. **🎭 Orchestrator**: 전체 팀 조정 및 작업 분배
#
# ### 🔧 주요 특징
# - **자율적 협업**: 에이전트들이 스스로 협력하여 목표 달성
# - **멀티모달**: 텍스트, 이미지, 파일 등 다양한 데이터 처리
# - **웹 자동화**: 실제 웹사이트 브라우징 및 상호작용
# - **코드 실행**: 실시간 코드 생성 및 실행
#
# ### 💡 사용 사례
# - 📊 데이터 분석 및 시각화
# - 🔍 웹 리서치 및 정보 수집
# - 📝 보고서 자동 생성
# - 🤖 복합적인 자동화 작업

# %% [markdown]
# ### `magentic_one.py` core code
#
# ```python
# def __init__(self, client: ChatCompletionClient, hil_mode: bool = False):
#     self.client = client
#     self._validate_client_capabilities(client)
#
#     fs = FileSurfer("FileSurfer", model_client=client)
#     ws = MultimodalWebSurfer("WebSurfer", model_client=client)
#     coder = MagenticOneCoderAgent("Coder", model_client=client)
#     executor = CodeExecutorAgent("Executor", code_executor=LocalCommandLineCodeExecutor())
#     agents: List[ChatAgent] = [fs, ws, coder, executor]
#     if hil_mode:
#         user_proxy = UserProxyAgent("User")
#         agents.append(user_proxy)
#     super().__init__(agents, model_client=client)
#
# ```

# %%
# MagenticOne을 사용한 자율적 작업 수행
import asyncio
from autogen_ext.models.openai import AzureOpenAIChatCompletionClient
from autogen_ext.teams.magentic_one import MagenticOne
from autogen_agentchat.ui import Console

from dotenv import load_dotenv
import os

load_dotenv()

# Azure OpenAI 설정
api_version = os.getenv("AZURE_OPENAI_API_VERSION")
api_key = os.getenv("AZURE_OPENAI_KEY")
azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
deployment_name = os.getenv("AZURE_OPENAI_DEPLOYMENT_NAME")

print("🔧 Azure OpenAI 설정:")
print(f"   Endpoint: {azure_endpoint}")
print(f"   Deployment: {deployment_name}")
print(f"   API Version: {api_version}")

azure_openai_chat_completion_client = AzureOpenAIChatCompletionClient(
    model=deployment_name,
    azure_endpoint=azure_endpoint,
    api_version=api_version,
    api_key=api_key,
)

print("\n🤖 MagenticOne 팀 초기화 중...")
client = azure_openai_chat_completion_client
m1 = MagenticOne(client=client)

print("📋 작업 실행:")
task = "마이크로소프트 현재 주가와 전망에 대해 알려줘"
print(f"   Task: {task}")

print("\n🚀 MagenticOne 팀 실행 시작...")
try:
    result = await Console(m1.run_stream(task=task))
    print(f"\n✅ 작업 완료!")
    print(f"Result: {result}")
except Exception as e:
    print(f"\n❌ 오류 발생: {e}")
    print("MagenticOne 실행 중 문제가 발생했습니다.")
# Out:
# 🔧 Azure OpenAI 설정:
#    Endpoint: https://eusonopenai.openai.azure.com/
#    Deployment: gpt-4o-mini
#    API Version: 2025-04-01-preview
#
# 🤖 MagenticOne 팀 초기화 중...
# 📋 작업 실행:
#    Task: 마이크로소프트 현재 주가와 전망에 대해 알려줘
#
# 🚀 MagenticOne 팀 실행 시작...
# /tmp/ipykernel_63870/2105966202.py:32: DeprecationWarning: Instantiating MagenticOne without a code_executor is deprecated. Provide a code_executor to clear this warning (e.g., code_executor=DockerCommandLineCodeExecutor() ).
#   m1 = MagenticOne(client=client)
# /home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/teams/magentic_one.py:209: UserWarning: Docker is not available or not running. Using LocalCommandLineCodeExecutor instead of the recommended DockerCommandLineCodeExecutor. For security, it is recommended to install Docker and ensure it's running before using code executors. To install Docker, visit: https://docs.docker.com/get-docker/
#   code_executor = create_default_code_executor()
# /home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/code_executors/__init__.py:80: UserWarning: Using LocalCommandLineCodeExecutor may execute code on the local machine which can be unsafe. For security, it is recommended to use DockerCommandLineCodeExecutor instead. To install Docker, visit: https://docs.docker.com/get-docker/
#   return LocalCommandLineCodeExecutor()
# /home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/teams/magentic_one.py:215: UserWarning: No approval function set for CodeExecutorAgent. This means code will be executed automatically without human oversight. For security, consider setting an approval_func to review and approve code before execution. See the CodeExecutorAgent documentation for examples of approval functions.
#   executor = CodeExecutorAgent("ComputerTerminal", code_executor=code_executor, approval_func=approval_func)
# ---------- TextMessage (user) ----------
# 마이크로소프트 현재 주가와 전망에 대해 알려줘
# ---------- TextMessage (MagenticOneOrchestrator) ----------
#
# We are working to address the following user request:
#
# 마이크로소프트 현재 주가와 전망에 대해 알려줘
#
#
# To answer this request we have assembled the following team:
#
# FileSurfer: An agent that can handle local files.
# WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
# Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
# ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).
#
#
# Here is an initial fact sheet to consider:
#
# 1. GIVEN OR VERIFIED FACTS
# - The request pertains to Microsoft, indicating an interest in the company's current stock price and outlook.
#
# 2. FACTS TO LOOK UP
# - The current stock price of Microsoft (symbol: MSFT). This can be found on financial news websites, stock market applications, or trading platforms (e.g., Yahoo Finance, Google Finance, Bloomberg).
# - Analyst forecasts and market outlook for Microsoft, which can be found through investment research platforms or financial news articles.
#
# 3. FACTS TO DERIVE
# - Potential trends in Microsoft’s stock price based on historical performance and current market conditions.
# - The impact of recent news, earnings reports, or broader market trends on Microsoft's future performance.
#
# 4. EDUCATED GUESSES
# - Given Microsoft's strong position in cloud computing and software services, one could guess that its long-term outlook remains positive, barring significant economic downturns or company-specific challenges.
# - Analysts may express bullish sentiments due to past performance indicators, although this should be verified through specific research.
#
#
# Here is the plan to follow as best as possible:
#
# - **Utilize WebSurfer** to search for the current stock price of Microsoft (MSFT) from reliable financial news sources.
# - **Request WebSurfer** to look for recent news articles or analyst reports that provide market outlook and forecasts for Microsoft, summarizing key insights.
# - **Gather and compile** the information obtained from WebSurfer on the current stock price and outlook, ensuring that the data is up-to-date and from credible sources.
# - **If necessary**, ask Coder to help visualize any historical stock performance trends based on data retrieved or to assist in deriving potential future trends.
# - **Compile the results** into a coherent response addressing the original request about Microsoft's current stock price and outlook.
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please search for the current stock price of Microsoft (MSFT) and review the latest analyst forecasts and market outlook. Summarize the findings.
# ---------- TextMessage (WebSurfer) ----------
# Web surfing error:
#
# Traceback (most recent call last):
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 440, in on_messages_stream
#     content = await self._generate_reply(cancellation_token=cancellation_token)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 467, in _generate_reply
#     await self._lazy_init()
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 324, in _lazy_init
#     browser = await self._playwright.chromium.launch(**launch_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/async_api/_generated.py", line 14465, in launch
#     await self._impl_obj.launch(
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_browser_type.py", line 98, in launch
#     await self._channel.send(
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 69, in send
#     return await self._connection.wrap_api_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 558, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# playwright._impl._errors.Error: BrowserType.launch: Executable doesn't exist at /home/euson/.cache/ms-playwright/chromium_headless_shell-1187/chrome-linux/headless_shell
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please assess the situation with WebSurfer and see if there's a way to download the required browser or provide an alternative solution to obtain the stock information.
# ---------- TextMessage (Coder) ----------
# The error message indicates that the Playwright environment requires a specific browser executable, which is not currently installed. Given that running the command directly is not an option, I will outline a solution using Python to fetch the current stock price and analyst outlook for Microsoft (MSFT) from an online financial data source via an API.
#
# I'll write a Python script that uses the `requests` library to get the stock price and analyst forecasts from a publicly available API. This way, we can bypass the need for a web browser entirely.
#
# Let's proceed with the following steps:
#
# 1. Use the `requests` library to query an online financial API for Microsoft's current stock price.
# 2. Parse the response to obtain the stock price and any available market outlook.
# 3. Summarize the findings.
#
# Here's the complete Python code to achieve this:
#
# ```python
# import requests
#
# def fetch_msft_stock_info():
#     # Define the URL for the financial API
#     url = "https://api.coingecko.com/api/v3/simple/price?ids=microsoft&vs_currencies=usd"
#
#     # Make a request to the API
#     response = requests.get(url)
#
#     if response.status_code == 200:
#         data = response.json()
#         msft_price = data['microsoft']['usd'] if 'microsoft' in data else None
#
#         # Check for analyst forecast news
#         analyst_forecast_url = "https://financialmodelingprep.com/api/v3/quote/MSFT?apikey=demo"
#         forecast_response = requests.get(analyst_forecast_url)
#
#         if forecast_response.status_code == 200:
#             forecast_data = forecast_response.json()
#             analyst_forecast = forecast_data[0]['changesPercentage'] if forecast_data else None
#
#             return msft_price, analyst_forecast
#         else:
#             return msft_price, None
#     else:
#         return None, None
#
# msft_price, analyst_forecast = fetch_msft_stock_info()
# print(f"Current MSFT Price: ${msft_price}")
# print(f"Analyst Forecast Change Percentage: {analyst_forecast}%")
# ```
#
# This code performs the following:
#
# - Fetches the current stock price of Microsoft in USD from a financial API.
# - Fetches analyst forecasts for Microsoft and gets the changes percentage.
# - Prints the current stock price and analyst forecast.
#
# Please run the above code to get the current stock price and outlook for Microsoft.
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please run the following Python script to retrieve the current stock price and outlook for Microsoft: ```python
# import requests
#
# def fetch_msft_stock_info():
#     url = "https://api.coingecko.com/api/v3/simple/price?ids=microsoft&vs_currencies=usd"
#     response = requests.get(url)
#     if response.status_code == 200:
#         data = response.json()
#         msft_price = data['microsoft']['usd'] if 'microsoft' in data else None
#         analyst_forecast_url = "https://financialmodelingprep.com/api/v3/quote/MSFT?apikey=demo"
#         forecast_response = requests.get(analyst_forecast_url)
#         if forecast_response.status_code == 200:
#             forecast_data = forecast_response.json()
#             analyst_forecast = forecast_data[0]['changesPercentage'] if forecast_data else None
#             return msft_price, analyst_forecast
#         else:
#             return msft_price, None
#     else:
#         return None, None
#
# msft_price, analyst_forecast = fetch_msft_stock_info()
# print(f"Current MSFT Price: ${msft_price}")
# print(f"Analyst Forecast Change Percentage: {analyst_forecast}%")```
# ---------- TextMessage (ComputerTerminal) ----------
# Current MSFT Price: $195.87
# Analyst Forecast Change Percentage: None%
# Current MSFT Price: $195.87
# Analyst Forecast Change Percentage: None%
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please search for recent articles or analyst forecasts regarding Microsoft's stock outlook and summarize any relevant findings.
# ---------- TextMessage (WebSurfer) ----------
# Web surfing error:
#
# Traceback (most recent call last):
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 440, in on_messages_stream
#     content = await self._generate_reply(cancellation_token=cancellation_token)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 467, in _generate_reply
#     await self._lazy_init()
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/autogen_ext/agents/web_surfer/_multimodal_web_surfer.py", line 324, in _lazy_init
#     browser = await self._playwright.chromium.launch(**launch_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/async_api/_generated.py", line 14465, in launch
#     await self._impl_obj.launch(
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_browser_type.py", line 98, in launch
#     await self._channel.send(
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 69, in send
#     return await self._connection.wrap_api_call(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/euson/Azure-AI-Agent/.venv/lib/python3.12/site-packages/playwright/_impl/_connection.py", line 558, in wrap_api_call
#     raise rewrite_error(error, f"{parsed_st['apiName']}: {error}") from None
# playwright._impl._errors.Error: BrowserType.launch: Executable doesn't exist at /home/euson/.cache/ms-playwright/chromium_headless_shell-1187/chrome-linux/headless_shell
# ╔════════════════════════════════════════════════════════════╗
# ║ Looks like Playwright was just installed or updated.       ║
# ║ Please run the following command to download new browsers: ║
# ║                                                            ║
# ║     playwright install                                     ║
# ║                                                            ║
# ║ <3 Playwright Team                                         ║
# ╚════════════════════════════════════════════════════════════╝
#
# ---------- TextMessage (MagenticOneOrchestrator) ----------
# Please write a script that retrieves the latest news articles or analyst reports regarding Microsoft’s stock outlook from a reliable financial news API.
# ---------- TextMessage (Coder) ----------
# To retrieve the latest news articles or analyst reports regarding Microsoft’s stock outlook, I can use a financial news API. Here’s how we'll proceed:
#
# 1. Identify a reliable financial news API that can provide the latest news articles about Microsoft.
# 2. Write a Python script that retrieves and prints relevant news articles based on Microsoft (symbol: MSFT).
#
# For this task, we'll use the News API which is a widely used service to get news articles. You'll need to sign up for an API key if you don't have one yet, or you can modify the code to use a specific API key. Below is the complete script to fetch the latest articles about Microsoft.
#
# Here's the Python code:
#
# ```python
# import requests
#
# def fetch_msft_news(api_key):
#     # Define the URL for the News API
#     url = f"https://newsapi.org/v2/everything?q=Microsoft&apiKey={api_key}"
#
#     # Make a request to the API
#     response = requests.get(url)
#
#     if response.status_code == 200:
#         articles = response.json().get('articles', [])
#         news_summary = []
#
#         for article in articles:
#             title = article.get('title')
#             url = article.get('url')
#             if title and url:
#                 news_summary.append(f"{title}: {url}")
#
#         return news_summary
#     else:
#         return []
#
# # Replace 'your_api_key' with your actual News API key
# api_key = 'your_api_key'
# msft_news = fetch_msft_news(api_key)
#
# print("Latest News Articles about Microsoft:")
# for news in msft_news:
#     print(news)
# ```
#
# ### Instructions for Use
# 1. Replace `'your_api_key'` with your actual API key obtained from the News API.
# 2. Run the script to fetch and display the latest news articles about Microsoft.
#
# This script retrieves news articles containing "Microsoft" in either the headline or the description from the News API and prints the titles with their URLs.
#
# Please execute this script to gather the latest news articles regarding Microsoft's stock outlook.
# ---------- TextMessage (MagenticOneOrchestrator) ----------
#
# We are working to address the following user request:
#
# 마이크로소프트 현재 주가와 전망에 대해 알려줘
#
#
# To answer this request we have assembled the following team:
#
# FileSurfer: An agent that can handle local files.
# WebSurfer: A helpful assistant with access to a web browser. Ask them to perform web searches, open pages, and interact with content (e.g., clicking links, scrolling the viewport, filling in form fields, etc.). It can also summarize the entire page, or answer questions based on the content of the page. It can also be asked to sleep and wait for pages to load, in cases where the page seems not yet fully loaded.
# Coder: A helpful and general-purpose AI assistant that has strong language skills, Python skills, and Linux command line skills.
# ComputerTerminal: A computer terminal that performs no other action than running Python scripts (provided to it quoted in ```python code blocks), or sh shell scripts (provided to it quoted in ```sh code blocks).
#
#
# Here is an initial fact sheet to consider:
#
# Here is the updated fact sheet reflecting our recent findings and observations regarding Microsoft's current stock price and outlook:
#
# 1. **GIVEN OR VERIFIED FACTS**
#    - The current stock price of Microsoft (MSFT) is $195.87.
#    - There was no current analyst forecast percentage available at this time.
#
# 2. **FACTS TO LOOK UP**
#    - Analyst forecasts and market outlook for Microsoft still need to be explored through investment research platforms or financial news articles.
#    - Recent news articles about Microsoft that may impact its stock outlook are to be retrieved from a financial news API.
#
# 3. **FACTS TO DERIVE**
#    - Potential trends in Microsoft’s stock price may still be analyzed based on historical performance and the current economic environment.
#    - The impact of recent news—including earnings reports, market trends, and industry developments—on Microsoft's future performance needs to be assessed.
#
# 4. **EDUCATED GUESSES**
#    - Given Microsoft's ongoing investments in cloud computing and software services, there is an educated guess that its long-term outlook will continue to be positive, despite potential economic challenges.
#    - Analysts may generally express bullish sentiments due to Microsoft's past performance indicators; however, such sentiments need verification through ongoing research.
#    - The lack of immediate analyst forecasts suggests a potential gap in current market sentiment analysis; investors might want to keep an eye on upcoming earnings calls or industry news that could influence analyst recommendations.
#    - There is a growing importance of keeping up with technological advancements and competition in the cloud sector, further coloring potential outlook forecasts.
#
# With these updates, we can continue to refine our search for comprehensive insights regarding Microsoft’s stock price and outlook.
#
#
# Here is the plan to follow as best as possible:
#
# ### Root Cause of Failure
# The primary issue in the last run was the inability of the WebSurfer to access browsing capabilities due to a missing executable for the headless browser required by the Playwright framework. This hindered our ability to retrieve real-time data and news articles, impacting our progress in gathering Microsoft’s stock outlook.
#
# ### New Plan
# To mitigate previous challenges and ensure we can gather the required information effectively, the following steps will be implemented:
#
# 1. **Use Existing Data from Previous Runs**:
#    - Continue utilizing the stock price already obtained ($195.87) and recognize the absence of analyst forecasts at this point.
#
# 2. **Implement Coder for API Queries**:
#    - Utilize Coder to script directly against financial news APIs to fetch articles and insights concerning Microsoft, bypassing the need for WebSurfer entirely.
#    - Prepare a straightforward script that uses a reliable news API to gather the latest articles on Microsoft.
#
# 3. **Establish API Key in Advance**:
#    - Ensure we have a valid API key (for instance from News API) that can be reused, eliminating potential delays in retrieving news articles.
#
# 4. **Structured Data Retrieval**:
#    - Focus on structured querying for both stock information and news, ensuring that the data gathered is relevant and timely.
#    - Consider default fallback scenarios in cases where API responses are empty or provide limited information.
#
# 5. **Documentation of Findings**:
#    - Maintain a well-organized repository of collected data, making it easy to reference current prices, analyst insights, or significant news articles.
#
# 6. **Utilize FileSurfer for Documentation**:
#    - If any relevant articles or results are found, use FileSurfer to store and document them for easy reference and further analysis.
#
# 7. **Regularly Review Errors**:
#    - Implement a brief review process for the scripts or methodologies used to fetch data, ensuring unexpected errors are logged and can be addressed promptly for future runs.
#
# By following this revised plan, we aim to effectively gather and analyze Microsoft's current stock price and outlook while avoiding previous missteps related to data retrieval challenges.
